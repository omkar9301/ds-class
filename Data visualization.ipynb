# %% [markdown]
# <a href="https://colab.research.google.com/github/omkar9301/ds-class/blob/main/Data%20visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Why to visualize data?
# - Data visualization is the practice of translating information into a visual context, such as a map or graph, to make data easier for the human brain to understand and pull insights from. The main goal of data visualization is to make it easier to identify patterns, trends and outliers in large data sets.
#     - Better analysis
#     - Quick action
#     - Identifying patterns
#     - Finding errors
#     - Understanding the story
#     - Exploring business insights
#     - Grasping the Latest Trends
#
# # What is Matplotlib?
#
# - Matplotlib is a python visualisation library, majorly used for plotting 2D data.
# - Matplotlib is a multi-platform data visualization library built on NumPy arrays and designed to work with the broader SciPy stack.
# - Matplotlib consists of several plots like line, bar, scatter, histogram etc.

# %%
##Import library
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Read external file
df = pd.read_csv('https://raw.githubusercontent.com/aishwaryamate/Datasets/main/cars.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# body-style            object
# drive-wheels          object
# engine-location       object
# width                float64
# height               float64
# engine-type           object
# engine-size            int64
# horsepower            object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %% [markdown]
# # Histogram

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
plt.hist(df['width'])
# Out:
# (array([ 1.,  2., 36., 39., 44., 42., 20.,  7.,  6.,  8.]),
#  array([60.3, 61.5, 62.7, 63.9, 65.1, 66.3, 67.5, 68.7, 69.9, 71.1, 72.3]),
#  <BarContainer object of 10 artists>)

# %%
#Set graph parameters
plt.rcParams['figure.figsize'] = (10,5) #Increases size of graph
plt.rcParams['figure.dpi'] = 250 # Used to increase pixels of images

# %%
plt.hist(df['width'])
# Out:
# (array([ 1.,  2., 36., 39., 44., 42., 20.,  7.,  6.,  8.]),
#  array([60.3, 61.5, 62.7, 63.9, 65.1, 66.3, 67.5, 68.7, 69.9, 71.1, 72.3]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['width'], edgecolor = 'black')
plt.xlabel('Width Values')
plt.ylabel('Frequency')
plt.title('Distribution Graph for Width')
# Out:
# Text(0.5, 1.0, 'Distribution Graph for Width')

# %%
df['symboling'].nunique()
# Out:
# 6

# %%
df['symboling'].unique()
# Out:
# array([ 3,  1,  2,  0, -1, -2], dtype=int64)

# %%
df.hist()
plt.tight_layout()

# %% [markdown]
# # Seaborn Countplot

# %%
#Importing the library

import seaborn as sns

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
sns.countplot(x = df['body-style'])
# Out:
# <Axes: xlabel='body-style', ylabel='count'>

# %%
sns.countplot(x = df['make'])
# Out:
# <Axes: xlabel='make', ylabel='count'>

# %%
sns.countplot(y = df['make'])
# Out:
# <Axes: xlabel='count', ylabel='make'>

# %% [markdown]
# # Scatterplot

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
sns.scatterplot(x = df['symboling'], y = df['width'] )
# Out:
# <Axes: xlabel='symboling', ylabel='width'>

# %%
sns.scatterplot(x = df['engine-size'], y = df['price'])
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %%
#Set theme
sns.set_theme(style='darkgrid', palette='rainbow')

# %%
sns.scatterplot(x = df['engine-size'], y = df['price'])
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %%
sns.scatterplot(x = df['engine-size'], y = df['city-mpg'])
# Out:
# <Axes: xlabel='engine-size', ylabel='city-mpg'>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
sns.scatterplot(x = df['engine-size'], y = df['price'])
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %%
sns.scatterplot(x = df['engine-size'], y = df['price'], hue = df['body-style'], edgecolor = 'black')
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %% [markdown]
# # Boxplot

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
sns.boxplot(df['price'], orient='h')
# Out:
# <Axes: >

# %%
sns.boxplot(x = df['price'], y = df['make'])
# Out:
# <Axes: xlabel='price', ylabel='make'>

# %%
df[df['make'] == 'renault']
# Out:
#      symboling normalized-losses     make fuel-type body-style drive-wheels  \
# 130          0                 ?  renault       gas      wagon          fwd
# 131          2                 ?  renault       gas  hatchback          fwd
#
#     engine-location  width  height engine-type  engine-size horsepower  \
# 130           front   66.5    55.2         ohc          132          ?
# 131           front   66.6    50.5         ohc          132          ?
#
#      city-mpg  highway-mpg  price
# 130        23           31   9295
# 131        23           31   9895
